# %% [markdown]
# <a href="https://colab.research.google.com/github/IreneEscudero8/Get2work/blob/master/tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # get2work
# > The Python library that makes you actually work.
#
# get2work is a CLI tool that gamifies your coding productivity. It celebrates your commits, roasts your git history, and shames you when you're slacking.
#
# **What you'll learn in this tutorial:**
# - How to install get2work
# - How to set up git hooks
# - How to use all the commands
# - How to configure AI roasts

# %%
# Install get2work
# !pip install get2work
# Out:
# Collecting get2work
#   Downloading get2work-0.2.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting anthropic>=0.20.0 (from get2work)
#   Downloading anthropic-0.95.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting apscheduler>=3.10.0 (from get2work)
#   Downloading apscheduler-3.11.2-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: gitpython>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from get2work) (3.1.46)
# Requirement already satisfied: psutil>=5.9.0 in /usr/local/lib/python3.12/dist-packages (from get2work) (5.9.5)
# Requirement already satisfied: pygame>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from get2work) (2.6.1)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from get2work) (2.32.4)
# Requirement already satisfied: rich>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from get2work) (13.9.4)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from get2work) (0.24.1)
# Requirement already satisfied: watchdog>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from get2work) (6.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.20.0->get2work) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.20.0->get2work) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.20.0->get2work) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.20.0->get2work) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.20.0->get2work) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.20.0->get2work) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.20.0->get2work) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.20.0->get2work) (4.15.0)
# Requirement already satisfied: tzlocal>=3.0 in /usr/local/lib/python3.12/dist-packages (from apscheduler>=3.10.0->get2work) (5.3.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython>=3.1.0->get2work) (4.0.12)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->get2work) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->get2work) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->get2work) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->get2work) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.0.0->get2work) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.0.0->get2work) (2.20.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->get2work) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->get2work) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->get2work) (0.0.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.0->get2work) (5.0.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic>=0.20.0->get2work) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic>=0.20.0->get2work) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.0.0->get2work) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic>=0.20.0->get2work) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic>=0.20.0->get2work) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic>=0.20.0->get2work) (0.4.2)
# Downloading get2work-0.2.0-py3-none-any.whl (15 kB)
# Downloading anthropic-0.95.0-py3-none-any.whl (627 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 627.7/627.7 kB 9.9 MB/s eta 0:00:00
# Downloading apscheduler-3.11.2-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: apscheduler, anthropic, get2work
# Successfully installed anthropic-0.95.0 apscheduler-3.11.2 get2work-0.2.0

# %% [markdown]
# ## Set up in your project
# Before get2work can celebrate your commits, you need to install the git hook once per project.
# This makes get2work automatically trigger every time you run `git commit` — no manual commands needed.

# %%
# Run this command in YOUR terminal (not here in Colab)
# inside the folder of the project you want to track

# cd your-project
# get2work install

# From that moment, every git commit triggers get2work automatically
print("Run 'get2work install' in your project folder in your terminal!")

# %% [markdown]
# ## Background watcher
# Want get2work running 24/7 without thinking about it?
# `get2work start` runs in the background watching for commits, checking for distractions every 2 minutes, and shaming you every 30 minutes if you haven't committed.

# %%
# Run this in a separate terminal (not here in Colab)
# It watches your repo 24/7

# get2work start

print("Run 'get2work start' in a separate terminal to keep it watching!")

# %% [markdown]
# ## Level system
# 8 levels from Hello World Survivor to Linus Would Be Proud
#
# | Level | Name | Commits needed |
# |---|---|---|
# | 1 | Hello World Survivor | 0 |
# | 2 | Tutorial Finisher | 10 |
# | 3 | Functional but Confused | 30 |
# | 4 | It Works Don't Touch It | 60 |
# | 5 | Commits with Confidence (wrongly) | 100 |
# | 6 | git push --force and it worked | 200 |
# | 7 | The Last Line of Defense | 400 |
# | 8 | Linus Would Be Proud | 700 |
#
# Every commit moves you closer to the next level

# %% [markdown]
# ## Check your status
# See your current level, streak and stats

# %%
# Check your level and stats
# !get2work status

# %% [markdown]
# ## Roast my commits
# Give your entire commit history to an AI and let it destroy you.
# It looks at your commit messages, what time you committed, how often,
# and constructs a full character assassination.
# This is the "big picture" roast, your whole vibe as a developer, judged.

# %%
# Optional: set your OpenAI key for AI roasts
# Replace with your own key from platform.openai.com
# Without a key, get2work uses funny hardcoded responses instead
import os
os.environ["OPENAI_API_KEY"] = "sk-tu-key-aqui"

# !get2work roast

# %% [markdown]
# ## Peer pressure
# See what other devs are shipping and feel bad about yourself.
# Two modes: stalk a specific dev, or get surprised by a random one from the internet.
# Perfect for when you need external motivation (or shame).

# %%
# Stalk a developer
# !get2work peer antfu

# Get shamed by a completely random dev from the internet
# You don't know who's coming — could be anyone
# !get2work randompeer

# %% [markdown]
# ## Vibe check
# This one is therapy. Sarcastic therapy, but therapy.
# The AI analyzes your commit patterns like a psychologist would —
# your work hours, your consistency, your messages —
# and gives you a mental health diagnosis as a developer.
# Not medical advice. But probably accurate.

# %%
# !get2work vibe

# %% [markdown]
# ## Accountability receipt
# See what you actually did today

# %%
# !get2work receipt

# %% [markdown]
# ## Git blame but make it personal
# Different from roast, this one goes commit by commit.
# Each individual commit gets its own personal comment.
# Did you commit at 3am? It will notice.
# Did you write "fix" 4 times in a row? It will notice.
# Line by line, commit by commit, no mercy.

# %%
# !get2work blame

# %% [markdown]
# ## Shame check
# No AI involved here — this one is pure math.
# Did you commit today? Yes → you're safe.
# No → get2work checks how many hours since your last commit
# and escalates the message accordingly.
# Under 4 hours: gentle nudge. Over 8 hours: full intervention. 💀

# %%
# !get2work shame

# %% [markdown]
# ## Pomodoro timer
# Focus sessions that count toward your level

# %%
# 25 minute pomodoro (change --minutes for shorter/longer)
# !get2work pomodoro --minutes 1

# %% [markdown]
# ## Distraction detector
# get2work watches your running processes in the background.
# If it catches you with Netflix, Spotify, Discord, TikTok, or any other
# non-work app open — it shames you in the terminal AND sends a system
# notification so you can't ignore it.
#
# Every time you get caught, it adds to your `distractions_caught` counter
# visible in `get2work status`. The shame is permanent and public (to yourself).

# %%
# Check if you're slacking right now
# !get2work distraction

# %% [markdown]
# ## Custom sounds
# Replace default meme sounds with your own
#
# ```python
# # Set custom sounds via environment variables
# import os
# os.environ["GET2WORK_SOUND_CELEBRATE"] = "/path/to/your/airhorn.mp3"
# os.environ["GET2WORK_SOUND_FUNERAL"] = "/path/to/sad_trombone.mp3"
# os.environ["GET2WORK_SOUND_SHAME"] = "/path/to/bruh.mp3"
# os.environ["GET2WORK_SOUND_LEVELUP"] = "/path/to/levelup.mp3"
# ```

# %% [markdown]
# ## That's it!
#
# Now go install it and actually ship something:
#
# ```bash
# pip install get2work
# cd your-project
# get2work install
# git commit -m "feat: i am being productive"
# ```
#
# https://github.com/IreneEscudero8/Get2work
